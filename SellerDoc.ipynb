# %% [markdown]
# <a href="https://colab.research.google.com/github/ajay-singh-quantal/Matthew-POC/blob/main/SellerDoc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (2.169.0)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.38.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2025.4.26)

# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build

# Path to your downloaded JSON key file
SERVICE_ACCOUNT_FILE = '/content/docusigntest-460407-6d2fbbc6f556.json'  # Replace with your JSON file path

# Your Google Spreadsheet ID (from the URL)
SPREADSHEET_ID = '1zom2jL2jhNmhTnvWzXPKbCvfrhQgYb1g1PKCMa3l1QQ'

# Sheet name exactly as it appears in your Google Sheet tabs
RANGE_NAME = "'CAR_Listing_Packet_Data__Chicago-Based__Specific_Area_Codes_.csv'!A1:O26"

# Define the scope for read-only access to Google Sheets
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# Authenticate with the service account JSON file
credentials = service_account.Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)

# Build the Sheets API client
service = build('sheets', 'v4', credentials=credentials)

# Prepare the API call to get values from the sheet
sheet = service.spreadsheets()
result = sheet.values().get(spreadsheetId=SPREADSHEET_ID,
                            range=RANGE_NAME).execute()

# Extract the data
values = result.get('values', [])

# Print the rows or show no data message
if not values:
    print('No data found.')
else:
    for row in values:
        print(row)
# Out:
# ['Effective Date', 'Seller Name', 'Contact Information', 'Property Address', 'Listing Price', 'Commission Rate', 'Listing Start Date', 'Listing End Date', 'Marketing Methods', 'Seller Disclosures', 'Broker Signature Date', 'Seller Signature Date', 'Termination Terms', 'Property Access', 'Dual Agency']
# ['2025-06-01', 'Mary Bennett', '(773) 818-2539', '30993 Mccoy Springs, West Loop, Chicago, IL', '$241,194', '2.03%', '2025-06-01', '2025-12-01', 'Online Listings, Direct Mail', 'No known issues', '2025-06-01', '2025-06-01', 'Mutual agreement', 'Lockbox', 'No']
# ['2025-06-08', 'Hunter George', '(872) 358-7735', '8639 Morales Branch, West Loop, Chicago, IL', '$258,148', '3.93%', '2025-06-08', '2025-12-08', 'MLS, Online Listings', 'Recently renovated', '2025-06-08', '2025-06-08', 'End of listing period', 'Appointment Only', 'No']
# ['2025-06-15', 'Miss Cynthia Taylor', '(773) 883-6266', '6054 Jones Burgs, Portage Park, Chicago, IL', '$599,972', '3.49%', '2025-06-15', '2025-12-15', 'Signage, Open Houses', 'No known issues', '2025-06-15', '2025-06-15', 'End of listing period', 'Open House Scheduled', 'No']
# ['2025-06-22', 'Alexandra Lewis', '(630) 842-8437', '492 Nelson Manors, Lakeview, Chicago, IL', '$1,174,065', '1.71%', '2025-06-22', '2025-12-22', 'Online Listings, Direct Mail', 'No known issues', '2025-06-22', '2025-06-22', 'End of listing period', 'Lockbox', 'No']
# ['2025-06-29', 'Lori Gibson', '(630) 367-0099', '65464 Austin Squares, Little Italy, Chicago, IL', '$1,545,215', '3.88%', '2025-06-29', '2025-12-29', 'Online Listings, Direct Mail', 'No known issues', '2025-06-29', '2025-06-29', 'End of listing period', 'Open House Scheduled', 'No']
# ['2025-07-06', 'Isabel Stone', '(872) 621-2611', '568 Wilson Trafficway, Old Town, Chicago, IL', '$207,290', '4.79%', '2025-07-06', '2026-01-05', 'Online Listings, Direct Mail', 'Minor repairs needed', '2025-07-06', '2025-07-06', 'Mutual agreement', 'Open House Scheduled', 'No']
# ['2025-07-13', 'Susan Jackson', '(773) 242-3236', '23557 Harrington Camp, Lincoln Park, Chicago, IL', '$1,344,262', '3.70%', '2025-07-13', '2026-01-12', 'MLS, Online Listings', 'Minor repairs needed', '2025-07-13', '2025-07-13', '30 days notice', 'Lockbox', 'No']
# ['2025-07-20', 'Jimmy Aguirre', '(872) 683-3633', '877 Gallagher Valley, Lincoln Park, Chicago, IL', '$524,459', '4.44%', '2025-07-20', '2026-01-19', 'Signage, Open Houses', 'Recently renovated', '2025-07-20', '2025-07-20', 'Mutual agreement', 'Appointment Only', 'No']
# ['2025-07-27', 'Andrea Gonzalez', '(872) 849-0245', '32655 Charlene Lights, Bridgeport, Chicago, IL', '$850,652', '3.01%', '2025-07-27', '2026-01-26', 'Online Listings, Direct Mail', 'No known issues', '2025-07-27', '2025-07-27', '30 days notice', 'Appointment Only', 'No']
# ['2025-08-03', 'Kaitlin Watson', '(872) 659-5080', '91721 Smith Plaza, Rogers Park, Chicago, IL', '$746,455', '4.43%', '2025-08-03', '2026-02-02', 'Signage, Open Houses', 'Minor repairs needed', '2025-08-03', '2025-08-03', 'End of listing period', 'Appointment Only', 'No']
# ['2025-08-10', 'Nicholas Martin', '(773) 812-7002', '90404 Williams Ridges Apt. 354, Hyde Park, Chicago, IL', '$1,804,718', '5.22%', '2025-08-10', '2026-02-09', 'Signage, Open Houses', 'Recently renovated', '2025-08-10', '2025-08-10', '30 days notice', 'Open House Scheduled', 'No']
# ['2025-08-17', 'Paul Mills Jr.', '(773) 325-1384', '671 Barrett Lodge, River North, Chicago, IL', '$1,933,822', '1.80%', '2025-08-17', '2026-02-16', 'Online Listings, Direct Mail', 'Recently renovated', '2025-08-17', '2025-08-17', 'Mutual agreement', 'Appointment Only', 'No']
# ['2025-08-24', 'Vanessa Schneider', '(872) 176-5990', '31399 Austin Mall, Andersonville, Chicago, IL', '$660,255', '5.10%', '2025-08-24', '2026-02-23', 'MLS, Online Listings', 'Recently renovated', '2025-08-24', '2025-08-24', 'Mutual agreement', 'Open House Scheduled', 'No']
# ['2025-08-31', 'Curtis Marks', '(630) 400-8811', '36008 Katherine Station Suite 258, Hyde Park, Chicago, IL', '$867,137', '4.12%', '2025-08-31', '2026-03-02', 'Online Listings, Direct Mail', 'No known issues', '2025-08-31', '2025-08-31', '30 days notice', 'Open House Scheduled', 'No']
# ['2025-09-07', 'William Munoz', '(773) 783-8403', '78966 Christopher Cliff Apt. 877, Lincoln Park, Chicago, IL', '$1,571,711', '4.06%', '2025-09-07', '2026-03-09', 'Online Listings, Direct Mail', 'Minor repairs needed', '2025-09-07', '2025-09-07', '30 days notice', 'Appointment Only', 'No']
# ['2025-09-14', 'Anthony Lee', '(630) 665-8867', '14257 Stacey Square Apt. 284, West Loop, Chicago, IL', '$647,747', '3.18%', '2025-09-14', '2026-03-16', 'Online Listings, Direct Mail', 'No known issues', '2025-09-14', '2025-09-14', 'Mutual agreement', 'Lockbox', 'No']
# ['2025-09-21', 'Gary Jones', '(773) 043-4585', '02563 Emily Motorway Apt. 222, Rogers Park, Chicago, IL', '$866,941', '5.41%', '2025-09-21', '2026-03-23', 'Signage, Open Houses', 'Recently renovated', '2025-09-21', '2025-09-21', 'End of listing period', 'Lockbox', 'No']
# ['2025-09-28', 'Wayne Mitchell', '(630) 128-3346', '3650 Victor Trail Suite 408, Rogers Park, Chicago, IL', '$757,034', '2.21%', '2025-09-28', '2026-03-30', 'Online Listings, Direct Mail', 'No known issues', '2025-09-28', '2025-09-28', '30 days notice', 'Lockbox', 'No']
# ['2025-10-05', 'John Cantrell', '(630) 398-5466', '92858 Melissa Shoals Suite 792, Logan Square, Chicago, IL', '$1,524,735', '3.77%', '2025-10-05', '2026-04-06', 'Online Listings, Direct Mail', 'No known issues', '2025-10-05', '2025-10-05', 'End of listing period', 'Appointment Only', 'No']
# ['2025-10-12', 'Jeffrey Johnson', '(872) 603-5990', '510 Hunt Haven, Uptown, Chicago, IL', '$962,969', '3.15%', '2025-10-12', '2026-04-13', 'Signage, Open Houses', 'No known issues', '2025-10-12', '2025-10-12', 'End of listing period', 'Appointment Only', 'No']
# ['2025-10-19', 'Mark Reid', '(630) 968-0796', '6176 Ashley Mount Apt. 313, Uptown, Chicago, IL', '$263,408', '4.77%', '2025-10-19', '2026-04-20', 'MLS, Online Listings', 'Recently renovated', '2025-10-19', '2025-10-19', 'End of listing period', 'Open House Scheduled', 'No']
# ['2025-10-26', 'Natalie Mendoza', '(312) 838-9829', '77621 Fisher Circles Apt. 915, Rogers Park, Chicago, IL', '$1,285,262', '4.57%', '2025-10-26', '2026-04-27', 'Online Listings, Direct Mail', 'No known issues', '2025-10-26', '2025-10-26', 'End of listing period', 'Open House Scheduled', 'No']
# ['2025-11-02', 'Frederick Adams', '(773) 038-2801', '7833 Sheila Unions, South Loop, Chicago, IL', '$401,946', '4.54%', '2025-11-02', '2026-05-04', 'MLS, Online Listings', 'No known issues', '2025-11-02', '2025-11-02', 'Mutual agreement', 'Lockbox', 'No']
# ['2025-11-09', 'Scott Ochoa', '(630) 781-5779', '0491 Lisa Square Suite 868, South Loop, Chicago, IL', '$608,325', '2.75%', '2025-11-09', '2026-05-11', 'Signage, Open Houses', 'Recently renovated', '2025-11-09', '2025-11-09', 'Mutual agreement', 'Open House Scheduled', 'No']
# ['2025-11-16', 'John Chase', '(630) 922-8736', '016 Rachel Turnpike Suite 056, Little Italy, Chicago, IL', '$883,809', '5.82%', '2025-11-16', '2026-05-18', 'MLS, Online Listings', 'No known issues', '2025-11-16', '2025-11-16', 'Mutual agreement', 'Open House Scheduled', 'No']

# %%
# Install PyJWT if you haven't already
# !pip install pyjwt cryptography --quiet

import jwt, time

# ─── CONFIGURATION ────────────────────────────────────────────────
INTEGRATION_KEY = "a8d08263-323c-4027-913e-7120df23e6e1"     # your Integration Key
USER_ID         = "49d3dcd6-49ab-4a1c-ae27-8fc9b4177604"     # your User ID
PRIVATE_KEY     = """-----BEGIN RSA PRIVATE KEY-----

8V4G/dIHuUh41wy+OayL6laDxPxBnQdGn5cNiYeZkVjuIbR3qanp
-----END RSA PRIVATE KEY-----"""

# ─── BUILD & SIGN JWT ─────────────────────────────────────────────
now = int(time.time())
payload = {
    "iss": INTEGRATION_KEY,
    "sub": USER_ID,
    "aud": "account-d.docusign.com",
    "iat": now,
    "exp": now + 3600,
    "scope": "signature impersonation"
}

jwt_assertion = jwt.encode(payload, PRIVATE_KEY, algorithm="RS256")

# ─── OUTPUT ────────────────────────────────────────────────────────
print("Here is your JWT assertion string:")
print(jwt_assertion)
# Out:
# Here is your JWT assertion string:
# eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJhOGQwODI2My0zMjNjLTQwMjctOTEzZS03MTIwZGYyM2U2ZTEiLCJzdWIiOiI0OWQzZGNkNi00OWFiLTRhMWMtYWUyNy04ZmM5YjQxNzc2MDQiLCJhdWQiOiJhY2NvdW50LWQuZG9jdXNpZ24uY29tIiwiaWF0IjoxNzQ3ODM1MjY0LCJleHAiOjE3NDc4Mzg4NjQsInNjb3BlIjoic2lnbmF0dXJlIGltcGVyc29uYXRpb24ifQ.PPJ3u7uN8iYr6rGXA7j_yrHGlab7qZ1KMrMevmvEPS_fUeaPSIpkouV9ys4XOEHdpSDqoY9DCiWAKiy_Hs2g-4jVaW3aa4OuJPV_yKMBQI6PMUU7BlLXfATG4_R02gB-D1Ipc2I7FuV223daTW8PzBorTyL97AfE8no4dKgBWt-LmP9dECJu_A4l5TTl9DR8EIOiUTAAw360u3wVahtbOdhDJxs83ZHvfE3JRng-1XKXMioOzjPeBfjxd0vgq028gK6-YirRQ8o3slvEfI3FVAKlqZgcsmSmgGJV62DII7k6zggcjYrydZTXPAWLSw_tGwyqpt0EyEOSJaHoZiHZWw

# %%
import requests

# ── Paste your full JWT Assertion here (no line breaks!) ────────────────
jwt_assertion = (
    "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJhOGQwODI2My0zMjNjLTQwMjctOTEzZS03MTIwZGYyM2U2ZTEiLCJzdWIiOiI0OWQzZGNkNi00OWFiLTRhMWMtYWUyNy04ZmM5YjQxNzc2MDQiLCJhdWQiOiJhY2NvdW50LWQuZG9jdXNpZ24uY29tIiwiaWF0IjoxNzQ3ODM1MjY0LCJleHAiOjE3NDc4Mzg4NjQsInNjb3BlIjoic2lnbmF0dXJlIGltcGVyc29uYXRpb24ifQ.PPJ3u7uN8iYr6rGXA7j_yrHGlab7qZ1KMrMevmvEPS_fUeaPSIpkouV9ys4XOEHdpSDqoY9DCiWAKiy_Hs2g-4jVaW3aa4OuJPV_yKMBQI6PMUU7BlLXfATG4_R02gB-D1Ipc2I7FuV223daTW8PzBorTyL97AfE8no4dKgBWt-LmP9dECJu_A4l5TTl9DR8EIOiUTAAw360u3wVahtbOdhDJxs83ZHvfE3JRng-1XKXMioOzjPeBfjxd0vgq028gK6-YirRQ8o3slvEfI3FVAKlqZgcsmSmgGJV62DII7k6zggcjYrydZTXPAWLSw_tGwyqpt0EyEOSJaHoZiHZWw"
)

token_response = requests.post(
    "https://account-d.docusign.com/oauth/token",
    headers={"Content-Type": "application/x-www-form-urlencoded"},
    data={
        "grant_type": "urn:ietf:params:oauth:grant-type:jwt-bearer",
        "assertion": jwt_assertion
    }
)

print("Status Code:", token_response.status_code)
print("Response Body:", token_response.text)

token_response.raise_for_status()
access_token = token_response.json()["access_token"]
print("\n✅ New Access Token:", access_token)
# Out:
# Status Code: 200
# Response Body: {"access_token":"eyJ0eXAiOiJNVCIsImFsZyI6IlJTMjU2Iiwia2lkIjoiNjgxODVmZjEtNGU1MS00Y2U5LWFmMWMtNjg5ODEyMjAzMzE3In0..5cxrtXhitl1MjQECUUyDShYuU-XbG2HKzUHHh692DNgXLeysfXjfXEWPwB0QOPbVxHk1H-p1l1XTpvisxPvpAD3BzkITVk89__GzYPyZCdZZ3LcW5_Edlg-ybCjDZi2rHcmNkSb6c5yREze0I5fPSuVGX5v8SKmYtjdU3dbwmrJGPvcIveKNG7H1TkBtcXAiPhmWYh7-Xx4pEAXKjaG0gJWkO18ubuYyo_f1wIN-1w6UXwQNYfgLMcmBuXwPa1n1QNIUqtbEdgDcKNh5YgwQeq8txvM7tcnIM1kAlNVEyvOCv0S1G6o1XEl9E1BlG3wAb3TgHbcoIuemYZhXeV5H0w","token_type":"Bearer","expires_in":3600,"scope":"signature impersonation"}
#
# ✅ New Access Token: eyJ0eXAiOiJNVCIsImFsZyI6IlJTMjU2Iiwia2lkIjoiNjgxODVmZjEtNGU1MS00Y2U5LWFmMWMtNjg5ODEyMjAzMzE3In0..5cxrtXhitl1MjQECUUyDShYuU-XbG2HKzUHHh692DNgXLeysfXjfXEWPwB0QOPbVxHk1H-p1l1XTpvisxPvpAD3BzkITVk89__GzYPyZCdZZ3LcW5_Edlg-ybCjDZi2rHcmNkSb6c5yREze0I5fPSuVGX5v8SKmYtjdU3dbwmrJGPvcIveKNG7H1TkBtcXAiPhmWYh7-Xx4pEAXKjaG0gJWkO18ubuYyo_f1wIN-1w6UXwQNYfgLMcmBuXwPa1n1QNIUqtbEdgDcKNh5YgwQeq8txvM7tcnIM1kAlNVEyvOCv0S1G6o1XEl9E1BlG3wAb3TgHbcoIuemYZhXeV5H0w

# %%
import requests

access_token = "eyJ0eXAiOiJNVCIsImFsZyI6IlJTMjU2Iiwia2lkIjoiNjgxODVmZjEtNGU1MS00Y2U5LWFmMWMtNjg5ODEyMjAzMzE3In0..5cxrtXhitl1MjQECUUyDShYuU-XbG2HKzUHHh692DNgXLeysfXjfXEWPwB0QOPbVxHk1H-p1l1XTpvisxPvpAD3BzkITVk89__GzYPyZCdZZ3LcW5_Edlg-ybCjDZi2rHcmNkSb6c5yREze0I5fPSuVGX5v8SKmYtjdU3dbwmrJGPvcIveKNG7H1TkBtcXAiPhmWYh7-Xx4pEAXKjaG0gJWkO18ubuYyo_f1wIN-1w6UXwQNYfgLMcmBuXwPa1n1QNIUqtbEdgDcKNh5YgwQeq8txvM7tcnIM1kAlNVEyvOCv0S1G6o1XEl9E1BlG3wAb3TgHbcoIuemYZhXeV5H0w"  # your token

# Call the UserInfo endpoint
resp = requests.get(
    "https://account-d.docusign.com/oauth/userinfo",
    headers={"Authorization": f"Bearer {access_token}"}
)
resp.raise_for_status()
userinfo = resp.json()

# Find the default account entry
default_acct = next(acc for acc in userinfo["accounts"] if acc["is_default"])

account_id = default_acct["account_id"]
base_uri   = default_acct["base_uri"]

print("Account ID:", account_id)
print("Base URI:  ", base_uri)
# Out:
# Account ID: fc96af79-0258-4a27-9f76-3ead91094b4c
# Base URI:   https://demo.docusign.net

# %%
# --- FIXED RECIPIENT & TEMPLATE SETTINGS ---
TEMPLATE_ID = "a70ad299-1f63-4173-9014-3ee4a5b4fbb1"
ROLE_NAME = "Signer 1"
RECIPIENT_NAME = "Ajay Singh"
RECIPIENT_EMAIL = "ajay.singh@quantaltech.ai"

# --- Extract headers and rows from the sheet ---
headers = values[0]
rows = values[1:]

# --- Loop through each row and send an envelope to the same recipient ---
for i, row in enumerate(rows, start=1):
    row_data = dict(zip(headers, row))

    # Build textTabs for non-checkbox fields
    text_tabs = [
        {"tabLabel": k, "value": v}
        for k, v in row_data.items()
        if v.strip() and not k.lower().startswith("checkbox_")
    ]

    # Build checkboxTabs from fields starting with 'checkbox_'
    checkbox_tabs = []
    for k, v in row_data.items():
        if k.lower().startswith("checkbox_"):
            checkbox_tabs.append({
                "tabLabel": k,
                "selected": "true" if v.strip().lower() in ["yes", "true", "1", "y"] else "false"
            })

    # Create envelope payload
    envelope_definition = {
        "status": "sent",
        "templateId": TEMPLATE_ID,
        "templateRoles": [
            {
                "email": RECIPIENT_EMAIL,
                "name": RECIPIENT_NAME,
                "roleName": ROLE_NAME,
                "tabs": {
                    "textTabs": text_tabs,
                    "checkboxTabs": checkbox_tabs
                }
            }
        ]
    }

    # Send the envelope
    url = f"{base_uri}/restapi/v2.1/accounts/{account_id}/envelopes"
    headers_ds = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }

    print(f"\n📤 Sending envelope for Row {i} to {RECIPIENT_NAME} <{RECIPIENT_EMAIL}>...")

    response = requests.post(url, headers=headers_ds, json=envelope_definition)
    print("Status Code:", response.status_code)
    print("Response Body:", response.text)

    if response.status_code == 201:
        env_id = response.json()["envelopeId"]
        print(f"✅ Row {i}: Envelope sent! Envelope ID: {env_id}")
    else:
        print(f"❌ Row {i}: Failed to send envelope.")
# Out:
# 📤 Sending envelope for Row 1 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"801d25b4-6869-4e1a-b91e-9a4ccd28bff5","uri":"/envelopes/801d25b4-6869-4e1a-b91e-9a4ccd28bff5","statusDateTime":"2025-05-21T13:50:29.0170000Z","status":"sent"}
# ✅ Row 1: Envelope sent! Envelope ID: 801d25b4-6869-4e1a-b91e-9a4ccd28bff5
#
# 📤 Sending envelope for Row 2 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"f373f9d5-e857-49e8-9720-828ba00c0060","uri":"/envelopes/f373f9d5-e857-49e8-9720-828ba00c0060","statusDateTime":"2025-05-21T13:50:35.2470000Z","status":"sent"}
# ✅ Row 2: Envelope sent! Envelope ID: f373f9d5-e857-49e8-9720-828ba00c0060
#
# 📤 Sending envelope for Row 3 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"0b3395c8-cae9-4b74-bd55-d8b05a13231d","uri":"/envelopes/0b3395c8-cae9-4b74-bd55-d8b05a13231d","statusDateTime":"2025-05-21T13:50:40.3570000Z","status":"sent"}
# ✅ Row 3: Envelope sent! Envelope ID: 0b3395c8-cae9-4b74-bd55-d8b05a13231d
#
# 📤 Sending envelope for Row 4 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"3a4a1b67-31d3-4c1e-bf4d-44a36b2fe9c8","uri":"/envelopes/3a4a1b67-31d3-4c1e-bf4d-44a36b2fe9c8","statusDateTime":"2025-05-21T13:50:45.4170000Z","status":"sent"}
# ✅ Row 4: Envelope sent! Envelope ID: 3a4a1b67-31d3-4c1e-bf4d-44a36b2fe9c8
#
# 📤 Sending envelope for Row 5 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"e26df0a2-f908-4bcf-8e92-6233f7b50f94","uri":"/envelopes/e26df0a2-f908-4bcf-8e92-6233f7b50f94","statusDateTime":"2025-05-21T13:50:50.3500000Z","status":"sent"}
# ✅ Row 5: Envelope sent! Envelope ID: e26df0a2-f908-4bcf-8e92-6233f7b50f94
#
# 📤 Sending envelope for Row 6 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"8c0a70bf-2693-4420-a19f-1d80f3df0c76","uri":"/envelopes/8c0a70bf-2693-4420-a19f-1d80f3df0c76","statusDateTime":"2025-05-21T13:50:55.7270000Z","status":"sent"}
# ✅ Row 6: Envelope sent! Envelope ID: 8c0a70bf-2693-4420-a19f-1d80f3df0c76
#
# 📤 Sending envelope for Row 7 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"7e473ec9-76fb-4a7e-8f5e-5764ea16cd3b","uri":"/envelopes/7e473ec9-76fb-4a7e-8f5e-5764ea16cd3b","statusDateTime":"2025-05-21T13:51:02.4870000Z","status":"sent"}
# ✅ Row 7: Envelope sent! Envelope ID: 7e473ec9-76fb-4a7e-8f5e-5764ea16cd3b
#
# 📤 Sending envelope for Row 8 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"a988778a-c9a7-4440-a705-37f7c973615c","uri":"/envelopes/a988778a-c9a7-4440-a705-37f7c973615c","statusDateTime":"2025-05-21T13:51:09.1030000Z","status":"sent"}
# ✅ Row 8: Envelope sent! Envelope ID: a988778a-c9a7-4440-a705-37f7c973615c
#
# 📤 Sending envelope for Row 9 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"8a46e156-0adb-4d9a-bbb1-bae9c8ed5390","uri":"/envelopes/8a46e156-0adb-4d9a-bbb1-bae9c8ed5390","statusDateTime":"2025-05-21T13:51:14.9000000Z","status":"sent"}
# ✅ Row 9: Envelope sent! Envelope ID: 8a46e156-0adb-4d9a-bbb1-bae9c8ed5390
#
# 📤 Sending envelope for Row 10 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"c1ea5ef4-bcfd-416f-b2ca-1727fb647b63","uri":"/envelopes/c1ea5ef4-bcfd-416f-b2ca-1727fb647b63","statusDateTime":"2025-05-21T13:51:19.6570000Z","status":"sent"}
# ✅ Row 10: Envelope sent! Envelope ID: c1ea5ef4-bcfd-416f-b2ca-1727fb647b63
#
# 📤 Sending envelope for Row 11 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"49bf3401-b3c6-41df-b365-f7d3f90a6625","uri":"/envelopes/49bf3401-b3c6-41df-b365-f7d3f90a6625","statusDateTime":"2025-05-21T13:51:25.5200000Z","status":"sent"}
# ✅ Row 11: Envelope sent! Envelope ID: 49bf3401-b3c6-41df-b365-f7d3f90a6625
#
# 📤 Sending envelope for Row 12 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"08ce32ce-5342-4fdd-ab21-3d2936c56756","uri":"/envelopes/08ce32ce-5342-4fdd-ab21-3d2936c56756","statusDateTime":"2025-05-21T13:51:32.6070000Z","status":"sent"}
# ✅ Row 12: Envelope sent! Envelope ID: 08ce32ce-5342-4fdd-ab21-3d2936c56756
#
# 📤 Sending envelope for Row 13 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"b2f8d601-cae7-45f1-97db-ebd781f78a3e","uri":"/envelopes/b2f8d601-cae7-45f1-97db-ebd781f78a3e","statusDateTime":"2025-05-21T13:51:37.5470000Z","status":"sent"}
# ✅ Row 13: Envelope sent! Envelope ID: b2f8d601-cae7-45f1-97db-ebd781f78a3e
#
# 📤 Sending envelope for Row 14 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"44e4b820-606e-44e5-b0ab-dd33d7f5239a","uri":"/envelopes/44e4b820-606e-44e5-b0ab-dd33d7f5239a","statusDateTime":"2025-05-21T13:51:42.9500000Z","status":"sent"}
# ✅ Row 14: Envelope sent! Envelope ID: 44e4b820-606e-44e5-b0ab-dd33d7f5239a
#
# 📤 Sending envelope for Row 15 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"cf90871d-1809-4783-bb0e-837913619724","uri":"/envelopes/cf90871d-1809-4783-bb0e-837913619724","statusDateTime":"2025-05-21T13:51:48.2830000Z","status":"sent"}
# ✅ Row 15: Envelope sent! Envelope ID: cf90871d-1809-4783-bb0e-837913619724
#
# 📤 Sending envelope for Row 16 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"08fb2ecd-3278-4e83-80d5-d2f5bac1e170","uri":"/envelopes/08fb2ecd-3278-4e83-80d5-d2f5bac1e170","statusDateTime":"2025-05-21T13:51:53.8100000Z","status":"sent"}
# ✅ Row 16: Envelope sent! Envelope ID: 08fb2ecd-3278-4e83-80d5-d2f5bac1e170
#
# 📤 Sending envelope for Row 17 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"65a70833-9932-40d5-9f26-3fa4b3d8dfc8","uri":"/envelopes/65a70833-9932-40d5-9f26-3fa4b3d8dfc8","statusDateTime":"2025-05-21T13:51:59.5230000Z","status":"sent"}
# ✅ Row 17: Envelope sent! Envelope ID: 65a70833-9932-40d5-9f26-3fa4b3d8dfc8
#
# 📤 Sending envelope for Row 18 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"1da1bf5a-3350-4ca1-ba51-4eacf04f4792","uri":"/envelopes/1da1bf5a-3350-4ca1-ba51-4eacf04f4792","statusDateTime":"2025-05-21T13:52:05.1970000Z","status":"sent"}
# ✅ Row 18: Envelope sent! Envelope ID: 1da1bf5a-3350-4ca1-ba51-4eacf04f4792
#
# 📤 Sending envelope for Row 19 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"e4608ab8-c21b-4095-8a98-6aba3a9b31c9","uri":"/envelopes/e4608ab8-c21b-4095-8a98-6aba3a9b31c9","statusDateTime":"2025-05-21T13:52:09.9300000Z","status":"sent"}
# ✅ Row 19: Envelope sent! Envelope ID: e4608ab8-c21b-4095-8a98-6aba3a9b31c9
#
# 📤 Sending envelope for Row 20 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"19e694d9-671e-41d4-b159-f5a36c957e18","uri":"/envelopes/19e694d9-671e-41d4-b159-f5a36c957e18","statusDateTime":"2025-05-21T13:52:15.3700000Z","status":"sent"}
# ✅ Row 20: Envelope sent! Envelope ID: 19e694d9-671e-41d4-b159-f5a36c957e18
#
# 📤 Sending envelope for Row 21 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"56fdcf69-e62b-4334-af15-39393ed4532f","uri":"/envelopes/56fdcf69-e62b-4334-af15-39393ed4532f","statusDateTime":"2025-05-21T13:52:22.2800000Z","status":"sent"}
# ✅ Row 21: Envelope sent! Envelope ID: 56fdcf69-e62b-4334-af15-39393ed4532f
#
# 📤 Sending envelope for Row 22 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"74f6b1f2-48b1-45d6-8e79-1f11ebfa5407","uri":"/envelopes/74f6b1f2-48b1-45d6-8e79-1f11ebfa5407","statusDateTime":"2025-05-21T13:52:28.3370000Z","status":"sent"}
# ✅ Row 22: Envelope sent! Envelope ID: 74f6b1f2-48b1-45d6-8e79-1f11ebfa5407
#
# 📤 Sending envelope for Row 23 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"b76af223-2a46-4f39-b8ba-4d3ddf9c06c5","uri":"/envelopes/b76af223-2a46-4f39-b8ba-4d3ddf9c06c5","statusDateTime":"2025-05-21T13:52:34.4330000Z","status":"sent"}
# ✅ Row 23: Envelope sent! Envelope ID: b76af223-2a46-4f39-b8ba-4d3ddf9c06c5
#
# 📤 Sending envelope for Row 24 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"af374461-ff9e-4f27-9939-49b297427d95","uri":"/envelopes/af374461-ff9e-4f27-9939-49b297427d95","statusDateTime":"2025-05-21T13:52:38.8770000Z","status":"sent"}
# ✅ Row 24: Envelope sent! Envelope ID: af374461-ff9e-4f27-9939-49b297427d95
#
# 📤 Sending envelope for Row 25 to Ajay Singh <ajay.singh@quantaltech.ai>...
# Status Code: 201
# Response Body: {"envelopeId":"8f3afbb6-b287-4f7e-9c3f-8df3a9de28a5","uri":"/envelopes/8f3afbb6-b287-4f7e-9c3f-8df3a9de28a5","statusDateTime":"2025-05-21T13:52:43.1500000Z","status":"sent"}
# ✅ Row 25: Envelope sent! Envelope ID: 8f3afbb6-b287-4f7e-9c3f-8df3a9de28a5
